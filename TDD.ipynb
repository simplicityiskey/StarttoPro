# %%
import OOP.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e85cad655c80> in <module>
# ----> 1 import OOP.ipynb
#
# ModuleNotFoundError: No module named 'OOP'
